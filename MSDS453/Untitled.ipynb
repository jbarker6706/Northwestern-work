# %%
import nltk   
from urllib import urlopen

url = "https://https://www.nasa.gov/mission_pages/swift/bursts/devoured-star.html display=50"    
html = urlopen(url).read()    
raw = nltk.clean_html(html)  
print(raw)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-e7920af68106> in <module>
#       1 import nltk
# ----> 2 from urllib import urlopen
#       3
#       4 url = "https://https://www.nasa.gov/mission_pages/swift/bursts/devoured-star.html display=50"
#       5 html = urlopen(url).read()
#
# ImportError: cannot import name 'urlopen' from 'urllib' (C:\Users\jbark\Anaconda3\lib\urllib\__init__.py)

# %%
import urllib

#link = "http://www.somesite.com/details.pl?urn=2344"
link = "https://https://www.nasa.gov/mission_pages/swift/bursts/devoured-star.html display=50"    
f = urllib.request.urlopen(link)
myfile = f.read()
print(myfile)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#
# ~\Anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#
# ~\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#
# ...

# %%
import nltk
from nltk.tokenize import TreebankWordTokenizer
import nltk
from nltk.corpus import stopwords
stopWords = set(stopwords.words('english'))

# %%
# Open the file in read mode 
text = open("Binary_Black_Hole.txt", "r") 
# Create an empty dictionary 
d = dict() 
  
# Loop through each line of the file 
for line in text: 
    # Remove the leading spaces and newline character 
    line = line.strip() 
  
    # Convert the characters in line to  
    # lowercase to avoid case mismatch 
    line = line.lower() 
  
    # Split the line into words 
    words = line.split(" ") 
  
    # Iterate over each word in line 
    for word in words: 
        # Check if the word is already in dictionary 
        if word in d: 
            # Increment count of word by 1 
            d[word] = d[word] + 1
        else: 
            # Add the word to dictionary with count 1 
            d[word] = 1

#import operator
#sorted_d = sorted(d.items(), key=operator.itemgetter(1))

# Print the contents of dictionary 
for key in list(d.keys()): 
#for key in list(sorted_d.keys()): 
    print(key, ":", d[key]) 
    #print(key, ":", sorted_d[key])
# Out:
# a : 68
# binary : 24
# black : 69
# hole : 16
# (bbh) : 1
# is : 36
# system : 2
# consisting : 1
# of : 83
# two : 9
# holes : 42
# in : 43
# close : 8
# orbit : 13
# around : 5
# each : 7
# other. : 3
# like : 2
# themselves, : 2
# are : 16
# often : 1
# divided : 1
# into : 4
# stellar : 4
# holes, : 3
# formed : 1
# either : 2
# as : 17
# remnants : 1
# high-mass : 1
# star : 2
# systems : 2
# or : 9
# by : 16
# dynamic : 1
# processes : 1
# and : 37
# mutual : 1
# capture, : 1
# supermassive : 7
# believed : 2
# to : 52
# be : 22
# result : 2
# galactic : 4
# mergers. : 2
#  : 25
# for : 14
# many : 1
# years, : 1
# proving : 1
# the : 189
# existence : 2
# was : 2
# made : 1
# difficult : 1
# because : 1
# nature : 1
# limited : 1
# means : 2
# detection : 2
# available. : 1
# however, : 3
# event : 7
# that : 13
# pair : 6
# were : 5
# merge, : 3
# an : 8
# immense : 1
# amount : 2
# energy : 11
# should : 1
# given : 1
# off : 2
# gravitational : 27
# waves, : 4
# with : 22
# ...

# %%
# Open the file in read mode 
text = open("Black_Hole.txt", "r") 
  
# Create an empty dictionary 
d = dict() 
  
# Loop through each line of the file 
for line in text: 
    # Remove the leading spaces and newline character 
    line = line.strip() 
  
    # Convert the characters in line to  
    # lowercase to avoid case mismatch 
    line = line.lower() 
  
    # Split the line into words 
    words = line.split(" ") 
  
    # Iterate over each word in line 
    for word in words: 
        # Check if the word is already in dictionary 
        if word in d: 
            # Increment count of word by 1 
            d[word] = d[word] + 1
        else: 
            # Add the word to dictionary with count 1 
            d[word] = 1
  
# Print the contents of dictionary 
for key in list(d.keys()): 
    print(key, ":", d[key])
# Out:
# a : 229
# black : 217
# hole : 79
# is : 120
# region : 9
# of : 327
# spacetime : 9
# exhibiting : 1
# gravitational : 36
# acceleration : 1
# so : 12
# strong : 9
# that : 115
# nothing—no : 1
# particles : 6
# or : 20
# even : 11
# electromagnetic : 5
# radiation : 13
# such : 41
# as : 64
# light—can : 1
# escape : 11
# from : 52
# it. : 4
# the : 601
# theory : 10
# general : 19
# relativity : 8
# predicts : 4
# sufficiently : 1
# compact : 13
# mass : 53
# can : 32
# deform : 1
# to : 180
# form : 9
# hole. : 24
# boundary : 9
# which : 31
# no : 16
# possible : 15
# called : 12
# event : 44
# horizon. : 8
# although : 5
# horizon : 24
# has : 16
# an : 47
# enormous : 2
# effect : 5
# on : 29
# fate : 1
# and : 95
# circumstances : 1
# object : 25
# crossing : 1
# it, : 3
# locally : 1
# detectable : 2
# features : 2
# appear : 7
# be : 56
# observed. : 1
# in : 141
# many : 9
# ways, : 1
# acts : 1
# like : 9
# ideal : 1
# body, : 1
# it : 55
# reflects : 1
# light. : 3
# ...

# %%
import re
from collections import Counter
words = re.findall(r'\w+', open('Black_Hole.txt').read().lower())
Counter(words).most_common(20)
# Out:
# [('the', 605),
#  ('of', 327),
#  ('a', 235),
#  ('black', 222),
#  ('to', 180),
#  ('in', 144),
#  ('hole', 135),
#  ('is', 123),
#  ('that', 117),
#  ('and', 97),
#  ('holes', 81),
#  ('mass', 74),
#  ('by', 73),
#  ('as', 64),
#  ('it', 63),
#  ('for', 63),
#  ('this', 61),
#  ('be', 56),
#  ('from', 52),
#  ('an', 47)]

# %%
words = re.findall(r'\w+', open('Black_Hole.txt').read().lower())
words
#Counter(words).most_common(20)
# Out:
# ['a',
#  'black',
#  'hole',
#  'is',
#  'a',
#  'region',
#  'of',
#  'spacetime',
#  'exhibiting',
#  'gravitational',
#  'acceleration',
#  'so',
#  'strong',
#  'that',
#  'nothing',
#  'no',
#  'particles',
#  'or',
#  'even',
#  'electromagnetic',
#  'radiation',
#  'such',
#  'as',
#  'light',
#  'can',
#  'escape',
#  'from',
#  'it',
#  'the',
#  'theory',
#  'of',
#  'general',
#  'relativity',
#  'predicts',
#  'that',
#  'a',
#  'sufficiently',
#  'compact',
#  'mass',
#  'can',
#  'deform',
#  'spacetime',
#  'to',
#  'form',
#  'a',
#  'black',
#  'hole',
#  'the',
#  'boundary',
#  'of',
#  'the',
#  'region',
#  'from',
#  'which',
#  'no',
#  'escape',
#  'is',
#  'possible',
#  'is',
#  'called',
#  'the',
#  'event',
#  'horizon',
#  'although',
#  'the',
#  'event',
#  'horizon',
#  'has',
#  'an',
#  'enormous',
#  'effect',
#  'on',
#  'the',
#  'fate',
#  'and',
#  'circumstances',
#  'of',
#  'an',
#  'object',
#  'crossing',
#  'it',
#  'no',
#  'locally',
# ...

# %%
print('Body: {}'.format(config['body']))
